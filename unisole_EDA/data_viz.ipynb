# %%
##
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y,color='red',linestyle="--")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("simple line plot")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Final_Data.csv")
df.head()
# Out:
#    Unnamed: 0 customer_id  age  gender       city signup_date  \
# 0           0       C1000   56  Female  Bangalore  2022-10-04
# 1           1       C1001   69  Female    Kolkata  2024-01-31
# 2           2       C1002   46    Male      Delhi  2023-11-07
# 3           3       C1003   32    Male    Kolkata  2023-01-29
# 4           4       C1004   60  Female     Mumbai  2023-04-02
#
#   last_purchase_date product  units_sold   price  ...  cleaned_city  country  \
# 0         2023-10-10       C           1  1200.0  ...     Bangalore    India
# 1         2024-10-13       C           3  1200.0  ...       Kolkata    India
# 2         2024-05-22       B          30  1200.0  ...         Delhi    India
# 3         2023-11-28       C           2  1200.0  ...       Kolkata    India
# 4         2023-04-12       C           2  1200.0  ...        Mumbai    India
#
#    customer_profile signup_month age_group  expected_revenue  \
# 0  Female_Bangalore      2022-10    senior            1200.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=df,x="age",kde=True)
plt.show()

# %%
##1. distribution viz
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.histplot(data=df['age'],kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
sns.boxplot(x=df['age'])
plt.title("Age outlier Detection")
plt.xlabel("age")
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0 customer_id  age  gender       city signup_date  \
# 0           0       C1000   56  Female  Bangalore  2022-10-04
# 1           1       C1001   69  Female    Kolkata  2024-01-31
# 2           2       C1002   46    Male      Delhi  2023-11-07
# 3           3       C1003   32    Male    Kolkata  2023-01-29
# 4           4       C1004   60  Female     Mumbai  2023-04-02
#
#   last_purchase_date product  units_sold   price  ...  cleaned_city  country  \
# 0         2023-10-10       C           1  1200.0  ...     Bangalore    India
# 1         2024-10-13       C           3  1200.0  ...       Kolkata    India
# 2         2024-05-22       B          30  1200.0  ...         Delhi    India
# 3         2023-11-28       C           2  1200.0  ...       Kolkata    India
# 4         2023-04-12       C           2  1200.0  ...        Mumbai    India
#
#    customer_profile signup_month age_group  expected_revenue  \
# 0  Female_Bangalore      2022-10    senior            1200.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,6))
sns.scatterplot(data=df,x="units_sold",y="expected_revenue")
plt.title("units sold VS total amount")
plt.xlabel("units sold")
plt.ylabel("total amount")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x="city",y="expected_revenue")
plt.title(" Revenue distribution")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="product")
plt.xlabel("product")
plt.ylabel("count")
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="Blues")
plt.title("Correlation Heatmap")
plt.show()

# %%
df['signup_date']=pd.to_datetime(df['signup_date'],errors='coerce')

df['signup_Month']=df['signup_date'].dt.to_period('M')

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df['signup_date']=pd.to_datetime(df['signup_date'],errors='coerce')

df['signup_Month']=df['signup_date'].dt.to_period('M')

plt.figure(figsize=(10,4))
df['signup_Month'].value_counts().sort_index().plot(kind='line',marker='o')
plt.title("monthly signup trend")
plt.xlabel("month")
plt.ylabel("customer signups")
plt.grid(True,linestyle="--",alpha=0.7)
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0 customer_id  age  gender       city signup_date  \
# 0           0       C1000   56  Female  Bangalore  2022-10-04
# 1           1       C1001   69  Female    Kolkata  2024-01-31
# 2           2       C1002   46    Male      Delhi  2023-11-07
# 3           3       C1003   32    Male    Kolkata  2023-01-29
# 4           4       C1004   60  Female     Mumbai  2023-04-02
#
#   last_purchase_date product  units_sold   price  ...  cleaned_city  country  \
# 0         2023-10-10       C           1  1200.0  ...     Bangalore    India
# 1         2024-10-13       C           3  1200.0  ...       Kolkata    India
# 2         2024-05-22       B          30  1200.0  ...         Delhi    India
# 3         2023-11-28       C           2  1200.0  ...       Kolkata    India
# 4         2023-04-12       C           2  1200.0  ...        Mumbai    India
#
#    customer_profile signup_month age_group  expected_revenue  \
# 0  Female_Bangalore      2022-10    senior            1200.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           200 non-null    int64
#  1   customer_id          200 non-null    object
#  2   age                  200 non-null    int64
#  3   gender               200 non-null    object
#  4   city                 200 non-null    object
#  5   signup_date          195 non-null    object
#  6   last_purchase_date   195 non-null    object
#  7   product              200 non-null    object
#  8   units_sold           200 non-null    int64
#  9   price                200 non-null    float64
#  10  total_amount         200 non-null    int64
#  11  income               200 non-null    float64
#  12  feedback_score       200 non-null    float64
#  13  device               200 non-null    object
#  14  promo_code           200 non-null    object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df[['age','income','units_sold','expected_revenue']])
plt.show()
