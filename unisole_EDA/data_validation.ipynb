# %%
import pandas as pd
df=pd.read_csv("eda_hypothetical_dataset.csv")

# %%
df.head()
# Out:
#   Customer_ID   Age  Gender       City Signup_Date Last_Purchase_Date Product  \
# 0       C1000  56.0  Female  Bangalore  2022-10-04         2023-10-10       C
# 1       C1001  69.0  Female    Kolkata  2024-01-31         2024-10-13       C
# 2       C1002  46.0    Male      Delhi  2023-11-07         2024-05-22       B
# 3       C1003  32.0    Male    Kolkata  2023-01-29         2023-11-28       C
# 4       C1004  60.0  Female     Mumbai  2023-04-02         2023-04-12       C
#
#    Units_Sold Price  Total_Amount   Income  Feedback_Score   Device  \
# 0           1   800           800  33119.0             2.0  Desktop
# 1           3   800          2400  47764.0             2.0  Desktop
# 2          30  1200          3600  49900.0             3.0  Desktop
# 3           2   800          1600  30213.0             4.0  Desktop
# 4           2   800          1600  62067.0             4.0  Desktop
#
#   Promo_Code  Fraud_Flag  Churned
# 0      LOYAL           0        1
# ...

# %%
## data validation
## convert col into date time
invalid_dates=df[df["Last_Purchase_Date"]<df["Signup_Date"]]

# %%
invalid_dates
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Age, Gender, City, Signup_Date, Last_Purchase_Date, Product, Units_Sold, Price, Total_Amount, Income, Feedback_Score, Device, Promo_Code, Fraud_Flag, Churned]
# Index: []

# %%
assert(df["Total_Amount"]==df["Units_Sold"]*df["Price"]).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 assert(df["Total_Amount"]==df["Units_Sold"]*df["Price"]).all()
#
# AssertionError:

# %%
assert(df["Age"]<=100).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 assert(df["Age"]<=100).all()
#
# AssertionError:

# %%
##.between(1,5)

# %%
valid_city=[]
assert df["City"].isin(valid_city).all()

# %%
## data publishing 
df.to_excel("finnal_df.xlsx")
